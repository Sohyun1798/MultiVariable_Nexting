# %% [markdown]
# # TD Lambda + Tile Coding for Heartbeat prediction

# %% [markdown]
# Import libraries: numpy, tile_coding
#
# tile_coding is our own library to be used as a linear approximation function.

# %%
import numpy as np
from tile_coding import *

# %% [markdown]
# ## 1. TD Lambda with tile coding for nexting
#
# * What we need more for this part
#
# 1.We need to reconsider the reward function.
#
#
# 2.Hyperparameters?

# %%
class Nexting:
    
    def __init__(self, reward_batch=1, exp_rate=0.1, lmbda=0.4, debug=True):
        self.actions = [-1, 0, 1]  # lower, 0 and upper beat
        self.state = (0,0)  # current heartbeat, predicted amount of change
        self.exp_rate = exp_rate
        self.end = False
        self.lmbda = lmbda
        self.rate_truncate = 1e-3
        self.reward_batch = reward_batch
        self.debug = debug
        self.step_num = 0
        
    def reset(self):
        pos = np.random.uniform(-0.3, 0.4) #?min max
        self.end = False
        self.state = (pos, 0)
        self.step_num = 0
        
    def takeAction(self, action):
        pos, gap = self.state
        
        #gap_new = gap + 0.001*action - 0.0025*np.cos(3*pos) #?
        gap_new = gap + 0.001*action
        gap_new = min(max(gap_new, GAP_BOUND[0]), GAP_BOUND[1])
        
        pos_new = pos + gap_new
        pos_new = min(max(pos_new, POSITION_BOUND[0][0]), POSITION_BOUND[0][1]) # need to change
        
        if pos_new == POSITION_BOUND[0][0]: #?
            #reach leftmost, set gap to 0
            gap_new = 0.005 # non zero
            
        elif pos_new == POSITION_BOUND[0][1]:
            gap_new = -0.005
             
        self.state = (pos_new, gap_new)
        
        return self.state ###
    
    def chooseAction(self, valueFunc):
        # choose an action based on the current state, 
        if np.random.uniform(0, 1) <= self.exp_rate:
            # random action
            return np.random.choice(self.actions)
        else:
            # greedy action
            values = {}
            for a in self.actions:
                value = valueFunc.value(self.state, a)
                values[a] = value
            return np.random.choice([k for k, v in values.items() if v==max(values.values())])
        
    def giveReward(self): # ***
        
        self.step_num += 1
        
        if self.step_num >= len(data):
            self.step_num = len(data) - 1
        
        if self.step_num % self.reward_batch == 0:
            pos, _ = self.state
            true_pos = data[self.step_num]
            
            if pos >= true_pos - 0.01 and pos <= true_pos + 0.01:
                return 0
        
        if self.step_num == len(data) - 1:
            self.end = True
        
        return -1
    
    def gt2tn(self, valueFunc, action, end):
        # only the last reward is non-zero
        reward = self.reward
        res = reward + valueFunc.value(self.state, action)
        
        return res
        
    def play(self, valueFunction, rounds=1):
        states_per_rounds = []
        
        for rnd in range(rounds):
            self.reset()
            action = self.chooseAction(valueFunction)
            
            actions = [action]
            states = [self.state]
            rewards = [-1]
            
            while not self.end:
                self.state = self.takeAction(action)  # next state
                self.reward = self.giveReward()
                
                states.append(self.state)
                action = self.chooseAction(valueFunction)
                
                if self.step_num % self.reward_batch == 0:
                    if self.debug:
                        print("total states {} end at {} reward {}".format(len(states), self.state, self.reward))
                        
                    T = len(states) - 1
                    
                    for t in range(T):
                        state = states[t]
                        gtlambda = 0
                        
                        for n in range(1, T-t):
                            gttn = self.gt2tn(valueFunction, action, t+n)
                            lambda_power = np.power(self.lmbda, n-1)
                            gtlambda += lambda_power*gttn
                            
                            if lambda_power < self.rate_truncate:
                                break
                                
                        gtlambda *= 1 - self.lmbda
                        
                        if lambda_power >= self.rate_truncate:
                            gtlambda += lambda_power*self.reward
                            
                        delta = gtlambda - valueFunction.value(self.state, action)
                        valueFunction.update(self.state, action, delta)
            
            states_per_rounds.append(states)
            
        return states_per_rounds

# %% [markdown]
# ## 2. Loading the dataset
#
# Please run the cell below if you don't have neurokit2 and mne as your python libraries. In case you have these two, you don't need to run the cell.

# %%
# !pip install neurokit2
# !pip install mne

# %%
import pandas as pd
from sklearn.preprocessing import normalize
import neurokit2 as nk
import mne
import matplotlib.pyplot as plt

# %%
file = "data/r04.edf"
data = mne.io.read_raw_edf(file)
raw_data = data.get_data()
# after normalization 
raw_data = normalize(raw_data,axis=1,norm="max")
# you can get the metadata included in the file and a list of all channels:
info = data.info
channels = data.ch_names

# cleanup the data
for i in range(len(raw_data)):
    raw_data[i] = nk.ecg_clean(raw_data[i],method="neurokit")

# feature range
POSITION_BOUND = [] #? range of heartbeat
for i in range(len(raw_data)):
    POSITION_BOUND.append([min(raw_data[i]), max(raw_data[i])])
# Out:
# Extracting EDF parameters from /Users/Textory/Desktop/Fall2022/cmput655/data/r04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %% [markdown]
# # 3. Settings to run TD lambda model for the dataset

# %% [markdown]
# * What we need more for this part
#
# 1.The experiment here is only for the first row of the dataset. We can use a simple loop for applying the model to our entire dataset.
#
#
# 2.We need to implement a progress bar of the model.
#
#
# 3.We need to change some hyper parameters.

# %%
data = raw_data[0]
GAP_BOUND = [-0.01, 0.01] #?
ACTIONS = [-1, 0, 1]
reward_batch = 300

feature_ranges = [POSITION_BOUND[0], GAP_BOUND]  # 2 features
number_tilings = 8
bins = [[100, 100] for _ in range(number_tilings)]
offsets = [[i, j] for i, j in zip(np.linspace(POSITION_BOUND[0][0], POSITION_BOUND[0][1], number_tilings), np.linspace(GAP_BOUND[0], GAP_BOUND[1], number_tilings))]

tilings = createTilings(feature_ranges, number_tilings, bins, offsets)

print("tiling shape: \n", tilings.shape)
print("offsets: \n", offsets)

valueFunc = qvalueFunction(tilings, ACTIONS, 0.3)

mc = Nexting(reward_batch=reward_batch)
predicted_states = mc.play(valueFunc, rounds=1)
# Out:
# tiling shape:
#  (8, 2, 99)
# offsets:
#  [[-0.3326277028214003, -0.01], [-0.22827675655421997, -0.0071428571428571435], [-0.12392581028703961, -0.004285714285714286], [-0.01957486401985925, -0.0014285714285714284], [0.08477608224732108, 0.0014285714285714284], [0.18912702851450147, 0.004285714285714285], [0.2934779747816818, 0.0071428571428571435], [0.39782892104886214, 0.01]]
# total states 301 end at (-0.22717107895113825, 0.001) reward -1
# total states 601 end at (0.260828921048862, -0.01) reward -1
# total states 901 end at (-0.28062770282140026, 0.003) reward -1
# total states 1201 end at (-0.19062770282140018, -0.006) reward -1
# total states 1501 end at (-0.07262770282140008, 0.007) reward -1
# total states 1801 end at (-0.24462770282140023, 0.007) reward -1
# total states 2101 end at (0.39482892104886214, 0.008) reward -1
# total states 2401 end at (0.10237229717859996, -0.001) reward -1
# total states 2701 end at (0.08837229717859994, 0.006) reward -1
# total states 3001 end at (0.09037229717859994, 0.003) reward -1
# total states 3301 end at (0.3438289210488621, -0.006) reward -1
# total states 3601 end at (-0.3116277028214003, -0.002) reward -1
# total states 3901 end at (0.3338289210488621, 0.0) reward -1
# total states 4201 end at (0.28882892104886204, -0.003) reward -1
# total states 4501 end at (0.21437229717860004, 0.003) reward -1
# total states 4801 end at (0.3408289210488621, -0.003) reward -1
# total states 5101 end at (-0.26362770282140024, 0.005) reward -1
# total states 5401 end at (0.3438289210488621, 0.001) reward -1
# total states 5701 end at (0.29482892104886205, -0.004) reward -1
# total states 6001 end at (0.10082892104886187, -0.002) reward -1
# total states 6301 end at (-0.28717107895113825, -0.01) reward -1
# total states 6601 end at (0.02182892104886183, -0.005) reward -1
# total states 6901 end at (0.11582892104886189, -0.003) reward -1
# total states 7201 end at (0.3598289210488621, 0.003) reward -1
# total states 7501 end at (0.16082892104886193, 0.007) reward -1
# total states 7801 end at (0.29982892104886205, 0.001) reward -1
# total states 8101 end at (-0.28862770282140027, 0.003) reward -1
# total states 8401 end at (0.39482892104886214, 0.001) reward -1
# total states 8701 end at (0.3638289210488621, -0.005) reward -1
# total states 9001 end at (-0.20717107895113834, 0.0) reward -1
# total states 9301 end at (-0.2611710789511383, -0.003) reward -1
# total states 9601 end at (0.04837229717859996, 0.003) reward -1
# total states 9901 end at (-0.3256277028214003, 0.003) reward -1
# total states 10201 end at (0.3163722971786001, 0.001) reward -1
# total states 10501 end at (0.10782892104886188, -0.004) reward -1
# total states 10801 end at (0.3588289210488621, -0.006) reward -1
# total states 11101 end at (0.28082892104886203, -0.005) reward -1
# total states 11401 end at (0.08782892104886186, 0.001) reward -1
# total states 11701 end at (0.31582892104886207, 0.002) reward -1
# total states 12001 end at (0.261828921048862, 0.0) reward -1
# total states 12301 end at (0.3368289210488621, 0.001) reward -1
# total states 12601 end at (0.31682892104886207, -0.004) reward -1
# total states 12901 end at (0.2833722971786001, 0.008) reward -1
# total states 13201 end at (0.20982892104886197, 0.002) reward -1
# total states 13501 end at (0.32282892104886207, 0.002) reward -1
# total states 13801 end at (0.3328289210488621, -0.005) reward -1
# total states 14101 end at (0.3778289210488621, 0.001) reward -1
# total states 14401 end at (0.3728289210488621, 0.002) reward -1
# total states 14701 end at (0.09482892104886187, -0.001) reward -1
# total states 15001 end at (0.3828289210488621, -0.005) reward -1
# total states 15301 end at (0.238828921048862, -0.006) reward -1
# total states 15601 end at (0.28782892104886204, -0.004) reward -1
# total states 15901 end at (0.18682892104886195, -0.01) reward -1
# total states 16201 end at (0.3498289210488621, 0.006) reward -1
# total states 16501 end at (0.04282892104886185, -0.006) reward -1
# total states 16801 end at (-0.27662770282140026, 0.007) reward -1
# total states 17101 end at (-0.014627702821400093, 0.009000000000000001) reward -1
# total states 17401 end at (0.29682892104886205, -0.006) reward -1
# total states 17701 end at (0.32182892104886207, 0.004) reward -1
# total states 18001 end at (-0.32217107895113833, -0.009000000000000001) reward -1
# total states 18301 end at (-0.037627702821400065, 0.01) reward -1
# total states 18601 end at (0.16782892104886193, 0.001) reward -1
# total states 18901 end at (-0.28762770282140027, 0.0) reward -1
# total states 19201 end at (-0.32017107895113833, -0.002) reward -1
# total states 19501 end at (0.22282892104886198, -0.008) reward -1
# total states 19801 end at (-0.15962770282140015, 0.009000000000000001) reward -1
# total states 20101 end at (-0.1076277028214001, 0.009000000000000001) reward -1
# total states 20401 end at (0.28782892104886204, -0.007) reward -1
# total states 20701 end at (0.267828921048862, -0.008) reward -1
# total states 21001 end at (0.1218289210488619, 0.0) reward -1
# total states 21301 end at (0.3743722971786002, 0.004) reward -1
# total states 21601 end at (0.18382892104886195, -0.007) reward -1
# total states 21901 end at (0.22382892104886198, -0.007) reward -1
# total states 22201 end at (-0.027171078951138072, -0.008) reward 0
# total states 22501 end at (0.28682892104886204, 0.002) reward -1
# total states 22801 end at (0.3578289210488621, -0.007) reward -1
# total states 23101 end at (-0.2066277028214002, -0.004) reward -1
# total states 23401 end at (0.03837229717859994, 0.009000000000000001) reward -1
# total states 23701 end at (-0.3006277028214003, 0.003) reward -1
# total states 24001 end at (-0.14662770282140014, 0.008) reward -1
# total states 24301 end at (-0.3196277028214003, 0.004) reward -1
# total states 24601 end at (-0.2956277028214003, 0.007) reward -1
# total states 24901 end at (0.10837229717859996, 0.006) reward -1
# total states 25201 end at (0.2823722971786001, 0.01) reward -1
# total states 25501 end at (-0.12117107895113816, -0.008) reward -1
# total states 25801 end at (-0.27062770282140025, 0.005) reward -1
# total states 26101 end at (-0.2811710789511383, -0.003) reward -1
# total states 26401 end at (0.15137229717859998, 0.004) reward -1
# total states 26701 end at (-0.1281710789511381, -0.009000000000000001) reward -1
# total states 27001 end at (0.20837229717860004, 0.01) reward -1
# total states 27301 end at (-0.31062770282140023, -0.006) reward -1
# total states 27601 end at (0.37937229717860016, 0.007) reward -1
# total states 27901 end at (0.264828921048862, -0.003) reward -1
# total states 28201 end at (0.28882892104886204, 0.002) reward -1
# total states 28501 end at (0.264828921048862, 0.0) reward -1
# total states 28801 end at (-0.16417107895113822, -0.009000000000000001) reward -1
# total states 29101 end at (0.04137229717859993, 0.007) reward -1
# total states 29401 end at (0.260828921048862, -0.005) reward -1
# total states 29701 end at (0.07282892104886188, -0.008) reward -1
# total states 30001 end at (0.15682892104886192, 0.002) reward -1
# total states 30301 end at (0.31782892104886207, 0.0) reward -1
# total states 30601 end at (0.0968289210488619, -0.009000000000000001) reward -1
# total states 30901 end at (-0.27662770282140026, 0.006) reward -1
# total states 31201 end at (0.25737229717860005, 0.005) reward -1
# total states 31501 end at (0.27937229717860007, 0.008) reward -1
# total states 31801 end at (0.25337229717860005, 0.008) reward -1
# total states 32101 end at (0.15682892104886192, -0.01) reward -1
# total states 32401 end at (0.31982892104886207, -0.005) reward -1
# total states 32701 end at (-0.14562770282140014, 0.006) reward -1
# total states 33001 end at (-0.19117107895113822, -0.002) reward -1
# total states 33301 end at (-0.0016277028214000747, 0.008) reward -1
# total states 33601 end at (0.228828921048862, -0.01) reward -1
# total states 33901 end at (-0.06317107895113813, -0.003) reward -1
# total states 34201 end at (0.3083722971786001, 0.002) reward -1
# total states 34501 end at (0.27837229717860007, 0.002) reward -1
# total states 34801 end at (0.27682892104886203, -0.005) reward -1
# total states 35101 end at (0.03682892104886192, -0.01) reward -1
# total states 35401 end at (0.20882892104886197, -0.007) reward -1
# total states 35701 end at (0.39782892104886214, -0.005) reward -1
# total states 36001 end at (-0.29262770282140027, -0.002) reward -1
# total states 36301 end at (0.31782892104886207, -0.01) reward -1
# total states 36601 end at (-0.2226277028214002, 0.007) reward -1
# total states 36901 end at (0.3053722971786001, 0.003) reward -1
# total states 37201 end at (0.18582892104886195, -0.01) reward -1
# total states 37501 end at (-0.2006277028214002, 0.006) reward -1
# total states 37801 end at (-0.16562770282140016, 0.007) reward -1
# total states 38101 end at (0.29582892104886205, 0.001) reward -1
# total states 38401 end at (-0.13462770282140013, 0.009000000000000001) reward -1
# total states 38701 end at (-0.19217107895113816, -0.009000000000000001) reward -1
# total states 39001 end at (0.15037229717859998, 0.01) reward -1
# total states 39301 end at (0.06782892104886193, -0.009000000000000001) reward -1
# total states 39601 end at (-0.3096277028214003, 0.006) reward -1
# total states 39901 end at (0.07337229717859993, 0.006) reward -1
# total states 40201 end at (0.002372297178599928, 0.007) reward -1
# total states 40501 end at (0.19582892104886196, -0.009000000000000001) reward -1
# total states 40801 end at (-0.2161710789511383, -0.006) reward -1
# total states 41101 end at (-0.24662770282140023, 0.005) reward -1
# total states 41401 end at (0.1723722971786, 0.002) reward -1
# total states 41701 end at (-0.23162770282140022, 0.005) reward -1
# total states 42001 end at (0.021372297178599925, 0.008) reward -1
# total states 42301 end at (0.013372297178599925, 0.009000000000000001) reward -1
# total states 42601 end at (0.21282892104886197, -0.009000000000000001) reward -1
# total states 42901 end at (-0.10117107895113817, -0.006) reward -1
# total states 43201 end at (-0.3136277028214003, 0.005) reward -1
# total states 43501 end at (0.14337229717859998, 0.005) reward -1
# total states 43801 end at (-0.26762770282140025, 0.005) reward -1
# total states 44101 end at (0.2663722971786001, 0.007) reward -1
# total states 44401 end at (0.10482892104886188, 0.001) reward -1
# total states 44701 end at (-0.13617107895113817, -0.009000000000000001) reward -1
# total states 45001 end at (0.04537229717859993, 0.009000000000000001) reward -1
# total states 45301 end at (0.02482892104886188, -0.005) reward -1
# total states 45601 end at (0.11082892104886188, 0.0) reward -1
# total states 45901 end at (0.13037229717859994, 0.01) reward -1
# total states 46201 end at (-0.08062770282140008, 0.007) reward -1
# total states 46501 end at (0.3378289210488621, -0.005) reward -1
# total states 46801 end at (0.10382892104886188, 0.002) reward -1
# total states 47101 end at (0.30482892104886206, 0.0) reward -1
# total states 47401 end at (-0.010171078951138092, -0.009000000000000001) reward 0
# total states 47701 end at (-0.25662770282140024, 0.005) reward -1
# total states 48001 end at (0.055372297178599914, 0.007) reward -1
# total states 48301 end at (-0.2976277028214003, -0.002) reward -1
# total states 48601 end at (-0.2216277028214002, 0.0) reward -1
# total states 48901 end at (0.3728289210488621, -0.006) reward -1
# total states 49201 end at (-0.2981710789511383, 0.0) reward -1
# total states 49501 end at (-0.20717107895113823, -0.003) reward -1
# total states 49801 end at (-0.2771710789511383, -0.001) reward -1
# total states 50101 end at (-0.12317107895113821, -0.005) reward -1
# total states 50401 end at (0.23882892104886194, 0.009000000000000001) reward -1
# total states 50701 end at (0.14537229717859998, 0.01) reward -1
# total states 51001 end at (0.3953722971786002, 0.003) reward -1
# total states 51301 end at (-0.15917107895113816, 0.0) reward -1
# total states 51601 end at (0.03582892104886189, -0.005) reward -1
# total states 51901 end at (0.32182892104886207, -0.004) reward -1
# total states 52201 end at (-0.15017107895113813, 0.005) reward -1
# total states 52501 end at (-0.28462770282140026, 0.001) reward -1
# total states 52801 end at (0.03282892104886187, -0.009000000000000001) reward -1
# total states 53101 end at (-0.04162770282140007, 0.007) reward -1
# total states 53401 end at (0.3768289210488622, 0.008) reward -1
# total states 53701 end at (0.03537229717859993, 0.009000000000000001) reward -1
# total states 54001 end at (-0.11917107895113821, -0.004) reward -1
# total states 54301 end at (0.057828921048861885, 0.007) reward -1
# total states 54601 end at (-0.23117107895113828, 0.0) reward -1
# total states 54901 end at (0.272828921048862, -0.009000000000000001) reward -1
# total states 55201 end at (0.06682892104886184, -0.006) reward -1
# total states 55501 end at (-0.005171078951138117, -0.01) reward 0
# total states 55801 end at (-0.03362770282140007, 0.002) reward -1
# total states 56101 end at (-0.29162770282140027, 0.001) reward -1
# total states 56401 end at (-0.050171078951138155, -0.01) reward -1
# total states 56701 end at (0.053828921048861895, -0.01) reward -1
# total states 57001 end at (0.31182892104886206, -0.005) reward -1
# total states 57301 end at (-0.21817107895113827, -0.003) reward -1
# total states 57601 end at (0.3268289210488621, -0.006) reward -1
# total states 57901 end at (-0.06717107895113816, -0.01) reward -1
# total states 58201 end at (0.3288289210488621, 0.0) reward -1
# total states 58501 end at (-0.07217107895113817, -0.007) reward -1
# total states 58801 end at (0.29682892104886205, 0.0) reward -1
# total states 59101 end at (0.29182892104886204, -0.001) reward -1
# total states 59401 end at (0.10382892104886188, 0.0) reward -1
# total states 59701 end at (0.18737229717860002, 0.007) reward -1
# total states 60001 end at (0.19782892104886196, -0.002) reward -1
# total states 60301 end at (0.00937229717859993, 0.007) reward 0
# total states 60601 end at (0.15282892104886192, -0.01) reward -1
# total states 60901 end at (-0.23062770282140022, 0.004) reward -1
# total states 61201 end at (-0.19917107895113825, 0.001) reward -1
# total states 61501 end at (-0.24017107895113832, 0.004) reward -1
# total states 61801 end at (-0.09517107895113816, -0.009000000000000001) reward -1
# total states 62101 end at (-0.04817107895113808, -0.009000000000000001) reward -1
# total states 62401 end at (-0.3236277028214003, 0.004) reward -1
# total states 62701 end at (-0.15517107895113816, -0.001) reward -1
# total states 63001 end at (0.07882892104886191, 0.0) reward -1
# total states 63301 end at (-0.04417107895113814, 0.0) reward -1
# total states 63601 end at (-0.005627702821400072, 0.005) reward 0
# total states 63901 end at (-0.18117107895113826, -0.001) reward -1
# total states 64201 end at (0.040372297178599914, 0.006) reward -1
# total states 64501 end at (-0.12917107895113814, -0.005) reward -1
# total states 64801 end at (0.06137229717859993, 0.008) reward -1
# total states 65101 end at (0.12037229717859996, 0.006) reward -1
# total states 65401 end at (0.16082892104886193, -0.006) reward -1
# total states 65701 end at (-0.2111710789511383, 0.0) reward -1
# total states 66001 end at (0.38682892104886213, 0.002) reward -1
# total states 66301 end at (0.251828921048862, -0.001) reward -1
# total states 66601 end at (0.244828921048862, -0.001) reward -1
# total states 66901 end at (0.29282892104886205, -0.002) reward -1
# total states 67201 end at (-0.23262770282140022, -0.001) reward -1
# total states 67501 end at (0.21437229717860004, 0.008) reward -1
# total states 67801 end at (0.38837229717860017, 0.01) reward -1
# total states 68101 end at (-0.0596277028214001, 0.005) reward -1
# total states 68401 end at (0.31882892104886207, -0.003) reward -1
# total states 68701 end at (-0.14217107895113817, -0.006) reward -1
# total states 69001 end at (-0.20517107895113823, 0.0) reward -1
# total states 69301 end at (-0.22817107895113828, -0.006) reward -1
# total states 69601 end at (-0.25662770282140024, 0.002) reward -1
# total states 69901 end at (0.3263722971786001, 0.006) reward -1
# total states 70201 end at (-0.2156277028214002, 0.005) reward -1
# total states 70501 end at (0.10637229717859996, 0.003) reward -1
# total states 70801 end at (0.21137229717859998, 0.006) reward -1
# total states 71101 end at (-0.14962770282140014, 0.005) reward -1
# total states 71401 end at (0.10082892104886187, 0.004) reward -1
# total states 71701 end at (0.21082892104886197, -0.005) reward -1
# total states 72001 end at (-0.14217107895113812, -0.004) reward -1
# total states 72301 end at (0.238828921048862, -0.004) reward -1
# total states 72601 end at (-0.05862770282140007, 0.005) reward -1
# total states 72901 end at (-0.0946277028214001, 0.002) reward -1
# total states 73201 end at (-0.10162770282140007, -0.001) reward -1
# total states 73501 end at (-0.15062770282140012, -0.001) reward -1
# total states 73801 end at (-0.13817107895113812, -0.009000000000000001) reward -1
# total states 74101 end at (-0.2361710789511383, -0.008) reward -1
# total states 74401 end at (0.18882892104886195, -0.002) reward -1
# total states 74701 end at (0.11782892104886189, 0.0) reward -1
# total states 75001 end at (-0.1016277028214001, 0.006) reward -1
# total states 75301 end at (0.27237229717860006, 0.003) reward -1
# total states 75601 end at (-0.15862770282140015, -0.002) reward -1
# total states 75901 end at (0.29782892104886205, -0.005) reward -1
# total states 76201 end at (-0.15862770282140015, -0.001) reward -1
# total states 76501 end at (-0.2266277028214001, -0.009000000000000001) reward -1
# total states 76801 end at (-0.2156277028214002, -0.005) reward -1
# total states 77101 end at (-0.05162770282140006, 0.003) reward -1
# total states 77401 end at (0.18182892104886195, 0.0) reward -1
# total states 77701 end at (-0.0731710789511382, 0.001) reward -1
# total states 78001 end at (-0.09817107895113822, -0.004) reward -1
# total states 78301 end at (-0.2171710789511383, 0.0) reward -1
# total states 78601 end at (0.28682892104886204, 0.005) reward -1
# total states 78901 end at (0.3598289210488621, 0.0) reward -1
# total states 79201 end at (0.251828921048862, 0.0) reward -1
# total states 79501 end at (0.38182892104886207, 0.002) reward -1
# total states 79801 end at (0.09482892104886187, -0.004) reward -1
# total states 80101 end at (-0.13862770282140013, 0.003) reward -1
# total states 80401 end at (-0.07562770282140008, -0.002) reward -1
# total states 80701 end at (-0.2126277028214002, 0.0) reward -1
# total states 81001 end at (0.259828921048862, -0.003) reward -1
# total states 81301 end at (-0.10817107895113817, -0.001) reward -1
# total states 81601 end at (0.20282892104886197, 0.002) reward -1
# total states 81901 end at (0.3778289210488621, 0.002) reward -1
# total states 82201 end at (0.38882892104886213, 0.002) reward -1
# total states 82501 end at (0.236828921048862, 0.0) reward -1
# total states 82801 end at (-0.03717107895113811, -0.002) reward 0
# total states 83101 end at (-0.21417107895113827, -0.001) reward -1
# total states 83401 end at (-0.24917107895113827, -0.002) reward -1
# total states 83701 end at (0.272828921048862, -0.006) reward -1
# total states 84001 end at (-0.1091710789511382, -0.001) reward -1
# total states 84301 end at (0.24882892104886203, 0.007) reward -1
# total states 84601 end at (-0.18517107895113827, -0.007) reward -1
# total states 84901 end at (-0.12462770282140012, -0.002) reward -1
# total states 85201 end at (-0.10962770282140011, 0.001) reward -1
# total states 85501 end at (-0.0986277028214001, 0.0) reward -1
# total states 85801 end at (-0.04162770282140005, -0.001) reward -1
# total states 86101 end at (-0.19062770282140018, 0.0) reward -1
# total states 86401 end at (0.227828921048862, 0.005) reward -1
# total states 86701 end at (0.31082892104886206, -0.002) reward -1
# total states 87001 end at (0.19382892104886207, -0.004) reward -1
# total states 87301 end at (-0.27717107895113824, 0.0) reward -1
# total states 87601 end at (-0.20117107895113823, -0.003) reward -1
# total states 87901 end at (0.28082892104886203, -0.003) reward -1
# total states 88201 end at (0.08082892104886191, 0.003) reward -1
# total states 88501 end at (-0.1311710789511382, 0.006) reward -1
# total states 88801 end at (-0.18717107895113824, 0.004) reward -1
# total states 89101 end at (-0.2781710789511383, 0.0) reward -1
# total states 89401 end at (-0.14062770282140014, -0.002) reward -1
# total states 89701 end at (-0.16062770282140015, 0.003) reward -1
# total states 90001 end at (0.3268289210488621, 0.002) reward -1
# total states 90301 end at (-0.07917107895113806, -0.004) reward -1
# total states 90601 end at (-0.1141710789511381, 0.007) reward -1
# total states 90901 end at (0.09782892104886187, 0.001) reward 0
# total states 91201 end at (0.15282892104886192, -0.003) reward -1
# total states 91501 end at (-0.18817107895113824, 0.003) reward -1
# total states 91801 end at (-0.11662770282140011, 0.001) reward -1
# total states 92101 end at (-0.3046277028214003, 0.003) reward -1
# total states 92401 end at (-0.01517107895113809, 0.001) reward -1
# total states 92701 end at (-0.11062770282140011, -0.001) reward -1
# total states 93001 end at (-0.1741710789511382, 0.0) reward -1
# total states 93301 end at (0.21237229717860004, 0.01) reward -1
# total states 93601 end at (-0.2846277028214002, 0.0) reward -1
# total states 93901 end at (0.05437229717859995, 0.009000000000000001) reward -1
# total states 94201 end at (0.248828921048862, 0.0) reward -1
# total states 94501 end at (-0.19117107895113827, 0.0) reward -1
# total states 94801 end at (0.244828921048862, -0.003) reward -1
# total states 95101 end at (0.253828921048862, -0.004) reward -1
# total states 95401 end at (0.3418289210488621, 0.001) reward -1
# total states 95701 end at (-0.29817107895113826, -0.008) reward -1
# total states 96001 end at (0.29082892104886204, -0.004) reward -1
# total states 96301 end at (-0.23962770282140022, 0.002) reward -1
# total states 96601 end at (0.28382892104886204, 0.003) reward -1
# total states 96901 end at (0.28582892104886204, 0.0) reward -1
# total states 97201 end at (0.246828921048862, 0.0) reward -1
# total states 97501 end at (-0.2761710789511383, 0.002) reward -1
# total states 97801 end at (-0.03862770282140009, 0.004) reward -1
# total states 98101 end at (0.10082892104886187, -0.001) reward -1
# total states 98401 end at (-0.2091710789511383, 0.001) reward -1
# total states 98701 end at (-0.23617107895113826, -0.01) reward -1
# total states 99001 end at (0.1213722971785999, 0.006) reward -1
# total states 99301 end at (-0.2226277028214002, 0.005) reward -1
# total states 99601 end at (-0.12962770282140013, 0.007) reward -1
# total states 99901 end at (0.27982892104886203, -0.004) reward -1
# total states 100201 end at (0.238828921048862, -0.006) reward -1
# total states 100501 end at (-0.3196277028214003, 0.002) reward -1
# total states 100801 end at (0.19237229717860002, 0.006) reward -1
# total states 101101 end at (0.17382892104886194, -0.003) reward -1
# total states 101401 end at (0.1358289210488619, -0.002) reward -1
# total states 101701 end at (0.25482892104886196, -0.001) reward -1
# total states 102001 end at (0.25282892104886195, 0.0) reward -1
# total states 102301 end at (0.18782892104886195, -0.007) reward -1
# total states 102601 end at (-0.24017107895113832, 0.001) reward -1
# total states 102901 end at (-0.1701710789511381, 0.005) reward -1
# total states 103201 end at (-0.1581710789511382, -0.008) reward -1
# total states 103501 end at (-0.2976277028214003, 0.002) reward -1
# total states 103801 end at (-0.06962770282140013, 0.002) reward -1
# total states 104101 end at (-0.3296277028214003, -0.002) reward -1
# total states 104401 end at (0.3628289210488621, 0.003) reward -1
# total states 104701 end at (0.23437229717860006, 0.008) reward -1
# total states 105001 end at (0.24037229717859995, 0.007) reward -1
# total states 105301 end at (0.21137229717859995, -0.001) reward -1
# total states 105601 end at (0.3308289210488621, -0.002) reward -1
# total states 105901 end at (0.28582892104886204, 0.0) reward -1
# total states 106201 end at (0.1458289210488619, 0.01) reward -1
# total states 106501 end at (0.3348289210488621, -0.005) reward -1
# total states 106801 end at (-0.22017107895113824, 0.005) reward -1
# total states 107101 end at (-0.033171078951138085, -0.009000000000000001) reward -1
# total states 107401 end at (-0.2156277028214002, 0.005) reward -1
# total states 107701 end at (-0.0996277028214001, 0.001) reward -1
# total states 108001 end at (-0.30217107895113826, -0.007) reward -1
# total states 108301 end at (0.19182892104886196, -0.001) reward -1
# total states 108601 end at (-0.23362770282140022, -0.002) reward -1
# total states 108901 end at (-0.14062770282140014, -0.002) reward -1
# total states 109201 end at (0.29082892104886204, -0.005) reward -1
# total states 109501 end at (0.3568289210488621, -0.005) reward -1
# total states 109801 end at (0.30482892104886206, -0.003) reward -1
# total states 110101 end at (-0.21717107895113827, -0.003) reward -1
# total states 110401 end at (-0.10962770282140011, -0.001) reward -1
# total states 110701 end at (-0.17562770282140017, -0.001) reward -1
# total states 111001 end at (0.28682892104886204, -0.003) reward -1
# total states 111301 end at (0.27982892104886203, -0.005) reward -1
# total states 111601 end at (0.3708289210488621, -0.003) reward -1
# total states 111901 end at (0.3508289210488621, -0.001) reward -1
# total states 112201 end at (0.39382892104886214, 0.002) reward -1
# total states 112501 end at (0.3438289210488621, -0.006) reward -1
# total states 112801 end at (-0.18817107895113827, 0.0) reward -1
# total states 113101 end at (0.3388289210488621, 0.0) reward -1
# total states 113401 end at (0.27382892104886203, -0.002) reward -1
# total states 113701 end at (0.3358289210488621, -0.003) reward -1
# total states 114001 end at (0.2878289210488621, 0.001) reward -1
# total states 114301 end at (0.3788289210488621, -0.004) reward -1
# total states 114601 end at (-0.28962770282140027, 0.003) reward -1
# total states 114901 end at (0.257828921048862, 0.0) reward -1
# total states 115201 end at (0.231828921048862, -0.001) reward -1
# total states 115501 end at (0.271828921048862, 0.003) reward -1
# total states 115801 end at (0.016372297178599903, 0.003) reward -1
# total states 116101 end at (0.23237229717860008, -0.002) reward -1
# total states 116401 end at (0.27982892104886203, 0.004) reward -1
# total states 116701 end at (0.3378289210488621, 0.0) reward -1
# total states 117001 end at (-0.28962770282140027, 0.005) reward -1
# total states 117301 end at (-0.17717107895113818, 0.004) reward -1
# total states 117601 end at (0.243828921048862, -0.002) reward -1
# total states 117901 end at (0.3698289210488621, 0.005) reward -1
# total states 118201 end at (-0.28362770282140026, 0.003) reward -1
# total states 118501 end at (-0.3116277028214003, -0.001) reward -1
# total states 118801 end at (-0.19662770282140019, 0.004) reward -1
# total states 119101 end at (-0.28462770282140026, -0.002) reward -1
# total states 119401 end at (-0.18662770282140018, 0.0) reward -1
# total states 119701 end at (0.257828921048862, -0.002) reward -1
# total states 120001 end at (0.3403722971786001, 0.002) reward -1
# total states 120301 end at (0.259828921048862, 0.001) reward -1
# total states 120601 end at (0.27582892104886203, -0.001) reward -1
# total states 120901 end at (0.3718289210488621, -0.007) reward -1
# total states 121201 end at (-0.2166277028214002, 0.002) reward -1
# total states 121501 end at (0.32182892104886207, -0.01) reward -1
# total states 121801 end at (0.29837229717860014, -0.001) reward -1
# total states 122101 end at (0.30982892104886206, 0.005) reward -1
# total states 122401 end at (0.27382892104886203, 0.004) reward -1
# total states 122701 end at (-0.24062770282140022, 0.002) reward -1
# total states 123001 end at (0.3293722971786001, 0.006) reward -1
# total states 123301 end at (-0.01717107895113816, -0.001) reward -1
# total states 123601 end at (0.3768289210488621, -0.008) reward -1
# total states 123901 end at (-0.2851710789511383, 0.001) reward -1
# total states 124201 end at (-0.3136277028214003, -0.002) reward -1
# total states 124501 end at (-0.24017107895113826, -0.009000000000000001) reward -1
# total states 124801 end at (-0.3296277028214003, -0.001) reward -1
# total states 125101 end at (-0.3056277028214003, -0.002) reward -1
# total states 125401 end at (-0.3256277028214003, -0.002) reward -1
# total states 125701 end at (0.08637229717859994, 0.006) reward -1
# total states 126001 end at (-0.21117107895113824, -0.004) reward -1
# total states 126301 end at (-0.3126277028214003, -0.003) reward -1
# total states 126601 end at (0.3848289210488621, -0.007) reward -1
# total states 126901 end at (-0.3176277028214003, 0.004) reward -1
# total states 127201 end at (-0.14062770282140014, 0.0) reward -1
# total states 127501 end at (-0.29362770282140027, -0.004) reward -1
# total states 127801 end at (-0.3026277028214003, -0.003) reward -1
# total states 128101 end at (-0.29362770282140027, 0.001) reward -1
# total states 128401 end at (-0.3326277028214003, 0.005) reward -1
# total states 128701 end at (0.15582892104886192, -0.01) reward -1
# total states 129001 end at (0.3638289210488621, -0.007) reward -1
# total states 129301 end at (-0.3206277028214003, -0.002) reward -1
# total states 129601 end at (-0.3266277028214003, 0.006) reward -1
# total states 129901 end at (-0.27762770282140026, -0.001) reward -1
# total states 130201 end at (-0.29162770282140027, -0.001) reward -1
# total states 130501 end at (-0.2956277028214003, -0.001) reward -1
# total states 130801 end at (-0.27962770282140026, 0.0) reward -1
# total states 131101 end at (-0.27962770282140026, 0.0) reward -1
# total states 131401 end at (-0.15562770282140015, 0.0) reward -1
# total states 131701 end at (-0.27962770282140026, 0.0) reward -1
# total states 132001 end at (-0.27862770282140026, 0.002) reward -1
# total states 132301 end at (-0.3281710789511383, -0.003) reward -1
# total states 132601 end at (0.017828921048861864, -0.01) reward -1
# total states 132901 end at (-0.08817107895113818, -0.001) reward -1
# total states 133201 end at (-0.27217107895113835, -0.005) reward -1
# total states 133501 end at (0.20582892104886197, 0.003) reward -1
# total states 133801 end at (-0.27062770282140025, 0.003) reward -1
# total states 134101 end at (0.3428289210488621, 0.002) reward -1
# total states 134401 end at (0.1218289210488619, -0.009000000000000001) reward -1
# total states 134701 end at (0.013828921048861917, -0.01) reward -1
# total states 135001 end at (0.18837229717860002, 0.007) reward -1
# total states 135301 end at (-0.27462770282140025, -0.003) reward -1
# total states 135601 end at (-0.27362770282140025, 0.003) reward -1
# total states 135901 end at (0.07782892104886188, -0.008) reward -1
# total states 136201 end at (0.27382892104886203, 0.0) reward -1
# total states 136501 end at (-0.3126277028214003, 0.005) reward -1
# total states 136801 end at (0.21282892104886197, -0.004) reward -1
# total states 137101 end at (0.0678289210488619, -0.009000000000000001) reward -1
# total states 137401 end at (0.07537229717859993, 0.01) reward -1
# total states 137701 end at (0.07837229717859992, -0.001) reward -1
# total states 138001 end at (-0.1371710789511382, 0.002) reward -1
# total states 138301 end at (-0.0881710789511381, -0.004) reward -1
# total states 138601 end at (-0.29517107895113825, -0.005) reward -1
# total states 138901 end at (-0.28762770282140027, -0.001) reward -1
# total states 139201 end at (0.39037229717860017, 0.003) reward -1
# total states 139501 end at (-0.13517107895113814, -0.006) reward -1
# total states 139801 end at (-0.18262770282140017, -0.002) reward -1
# total states 140101 end at (-0.29062770282140027, -0.001) reward -1
# total states 140401 end at (0.11937229717859998, 0.005) reward -1
# total states 140701 end at (-0.3326277028214003, 0.005) reward -1
# total states 141001 end at (-0.0986277028214001, 0.007) reward -1
# total states 141301 end at (-0.16617107895113825, 0.007) reward -1
# total states 141601 end at (0.258828921048862, -0.002) reward -1
# total states 141901 end at (-0.14162770282140014, -0.001) reward -1
# total states 142201 end at (-0.13662770282140013, -0.001) reward -1
# total states 142501 end at (0.3448289210488621, -0.002) reward -1
# total states 142801 end at (0.18237229717859996, 0.008) reward -1
# total states 143101 end at (0.08637229717859991, 0.01) reward -1
# total states 143401 end at (0.03782892104886193, -0.008) reward -1
# total states 143701 end at (-0.023171078951138145, 0.008) reward -1
# total states 144001 end at (-0.021171078951138123, -0.001) reward -1
# total states 144301 end at (0.10482892104886188, 0.004) reward -1
# total states 144601 end at (-0.17162770282140016, 0.0) reward -1
# total states 144901 end at (0.27982892104886203, -0.003) reward -1
# total states 145201 end at (0.267828921048862, -0.008) reward -1
# total states 145501 end at (0.28782892104886204, -0.006) reward -1
# total states 145801 end at (-0.13817107895113814, 0.001) reward -1
# total states 146101 end at (-0.13217107895113814, 0.001) reward -1
# total states 146401 end at (0.3848289210488621, -0.007) reward -1
# total states 146701 end at (0.05982892104886193, -0.008) reward -1
# total states 147001 end at (0.3778289210488621, -0.007) reward -1
# total states 147301 end at (0.2693722971786, 0.01) reward -1
# total states 147601 end at (-0.19162770282140018, 0.007) reward -1
# total states 147901 end at (0.06082892104886189, -0.009000000000000001) reward -1
# total states 148201 end at (-0.2966277028214003, 0.001) reward -1
# total states 148501 end at (-0.16117107895113822, -0.003) reward -1
# total states 148801 end at (-0.28317107895113824, -0.006) reward -1
# total states 149101 end at (0.39782892104886214, -0.005) reward -1
# total states 149401 end at (0.251828921048862, 0.001) reward -1
# total states 149701 end at (-0.27262770282140025, 0.0) reward -1
# total states 150001 end at (0.3358289210488621, 0.002) reward -1
# total states 150301 end at (0.269828921048862, -0.006) reward -1
# total states 150601 end at (0.28982892104886204, 0.001) reward -1
# total states 150901 end at (-0.010627702821400069, 0.004) reward -1
# total states 151201 end at (0.269828921048862, 0.005) reward -1
# total states 151501 end at (0.20182892104886196, 0.001) reward -1
# total states 151801 end at (-0.1971710789511382, -0.007) reward -1
# total states 152101 end at (-0.2976277028214003, 0.0) reward -1
# total states 152401 end at (0.3268289210488621, -0.002) reward -1
# total states 152701 end at (-0.030171078951138127, -0.005) reward -1
# total states 153001 end at (-0.02017107895113816, 0.004) reward -1
# total states 153301 end at (0.3348289210488621, 0.005) reward -1
# total states 153601 end at (-0.0676277028214001, 0.002) reward -1
# total states 153901 end at (0.011828921048861922, -0.01) reward 0
# total states 154201 end at (0.0848289210488619, -0.001) reward -1
# total states 154501 end at (0.2728289210488621, -0.003) reward -1
# total states 154801 end at (0.31282892104886206, -0.003) reward -1
# total states 155101 end at (0.09682892104886187, -0.001) reward -1
# total states 155401 end at (0.28282892104886204, -0.002) reward -1
# total states 155701 end at (0.20782892104886197, -0.002) reward -1
# total states 156001 end at (0.07182892104886197, -0.003) reward -1
# total states 156301 end at (0.3368289210488621, 0.001) reward -1
# total states 156601 end at (-0.07517107895113817, 0.007) reward -1
# total states 156901 end at (0.3163722971786001, 0.009000000000000001) reward -1
# total states 157201 end at (-0.19062770282140018, 0.004) reward -1
# total states 157501 end at (-0.07062770282140007, 0.007) reward -1
# total states 157801 end at (-0.1446277028214002, -0.003) reward -1
# total states 158101 end at (0.30482892104886206, 0.0) reward -1
# total states 158401 end at (-0.09717107895113808, -0.01) reward -1
# total states 158701 end at (0.3608289210488621, -0.006) reward -1
# total states 159001 end at (-0.20162770282140022, -0.002) reward -1
# total states 159301 end at (-0.28062770282140026, 0.001) reward -1
# total states 159601 end at (0.30537229717860004, 0.009000000000000001) reward -1
# total states 159901 end at (-0.12762770282140012, 0.008) reward -1
# total states 160201 end at (-0.2611710789511383, -0.004) reward -1
# total states 160501 end at (-0.01362770282140005, 0.0) reward -1
# total states 160801 end at (0.261828921048862, 0.002) reward -1
# total states 161101 end at (-0.03817107895113815, -0.002) reward -1
# total states 161401 end at (-0.2216277028214002, 0.0) reward -1
# total states 161701 end at (0.2833722971786001, 0.008) reward -1
# total states 162001 end at (0.3573722971786002, 0.006) reward -1
# total states 162301 end at (0.20182892104886196, -0.007) reward -1
# total states 162601 end at (-0.031171078951138166, -0.009000000000000001) reward -1
# total states 162901 end at (0.21537229717859996, 0.008) reward -1
# total states 163201 end at (0.22037229717860002, 0.007) reward -1
# total states 163501 end at (0.12037229717859999, 0.005) reward -1
# total states 163801 end at (0.258828921048862, -0.006) reward -1
# total states 164101 end at (0.3418289210488621, -0.006) reward -1
# total states 164401 end at (0.27982892104886203, -0.004) reward -1
# total states 164701 end at (-0.23362770282140022, -0.001) reward -1
# total states 165001 end at (-0.28662770282140027, -0.001) reward -1
# total states 165301 end at (-0.016171078951138132, -0.007) reward -1
# total states 165601 end at (0.3648289210488621, 0.0) reward -1
# total states 165901 end at (-0.1311710789511382, -0.005) reward -1
# total states 166201 end at (-0.13262770282140013, 0.002) reward -1
# total states 166501 end at (0.31382892104886206, -0.009000000000000001) reward -1
# total states 166801 end at (-0.26162770282140024, 0.002) reward -1
# total states 167101 end at (-0.25862770282140024, 0.003) reward -1
# total states 167401 end at (0.267828921048862, 0.002) reward -1
# total states 167701 end at (-0.17462770282140017, 0.001) reward -1
# total states 168001 end at (0.08382892104886186, -0.006) reward -1
# total states 168301 end at (0.28582892104886204, -0.003) reward -1
# total states 168601 end at (0.253828921048862, -0.002) reward -1
# total states 168901 end at (0.3588289210488621, 0.002) reward -1
# total states 169201 end at (0.24137229717860006, 0.005) reward -1
# total states 169501 end at (0.259828921048862, 0.0) reward -1
# total states 169801 end at (0.11437229717859984, 0.009000000000000001) reward -1
# total states 170101 end at (-0.3256277028214003, 0.003) reward -1
# total states 170401 end at (-0.10817107895113819, -0.004) reward -1
# total states 170701 end at (-0.26062770282140024, 0.004) reward -1
# total states 171001 end at (-0.16517107895113822, -0.005) reward -1
# total states 171301 end at (-0.18917107895113824, 0.001) reward -1
# total states 171601 end at (-0.07662770282140013, -0.002) reward -1
# total states 171901 end at (0.3428289210488621, -0.007) reward -1
# total states 172201 end at (-0.3006277028214003, 0.007) reward -1
# total states 172501 end at (0.29337229717860003, 0.008) reward -1
# total states 172801 end at (0.29882892104886205, -0.001) reward -1
# total states 173101 end at (-0.24862770282140023, 0.0) reward -1
# total states 173401 end at (0.17182892104886194, -0.01) reward -1
# total states 173701 end at (-0.09462770282140015, 0.009000000000000001) reward -1
# total states 174001 end at (0.257828921048862, -0.006) reward -1
# total states 174301 end at (0.31882892104886207, -0.005) reward -1
# total states 174601 end at (-0.08117107895113812, -0.007) reward -1
# total states 174901 end at (0.04082892104886191, -0.01) reward -1
# total states 175201 end at (-0.14217107895113817, -0.003) reward -1
# total states 175501 end at (-0.3121710789511382, -0.006) reward -1
# total states 175801 end at (-0.08117107895113809, -0.008) reward -1
# total states 176101 end at (-0.26662770282140025, 0.002) reward -1
# total states 176401 end at (-0.12917107895113825, -0.006) reward -1
# total states 176701 end at (0.36382892104886216, 0.009000000000000001) reward -1
# total states 177001 end at (0.3278289210488621, 0.003) reward -1
# total states 177301 end at (0.008372297178599886, 0.009000000000000001) reward 0
# total states 177601 end at (0.29182892104886204, -0.003) reward -1
# total states 177901 end at (0.06382892104886184, 0.006) reward -1
# total states 178201 end at (-0.03662770282140006, -0.009000000000000001) reward 0
# total states 178501 end at (0.04737229717859993, 0.008) reward -1
# total states 178801 end at (0.05882892104886187, -0.008) reward -1
# total states 179101 end at (0.3648289210488621, 0.0) reward -1
# total states 179401 end at (-0.25362770282140024, 0.007) reward -1
# total states 179701 end at (0.22637229717860005, 0.005) reward -1
# total states 180001 end at (0.07037229717859994, -0.004) reward -1
# total states 180301 end at (0.21737229717860002, 0.008) reward -1
# total states 180601 end at (0.07337229717859994, 0.002) reward -1
# total states 180901 end at (0.11882892104886189, -0.009000000000000001) reward -1
# total states 181201 end at (0.1843722971786, 0.006) reward -1
# total states 181501 end at (0.28582892104886204, -0.007) reward -1
# total states 181801 end at (-0.2126277028214002, 0.002) reward -1
# total states 182101 end at (0.31082892104886206, -0.009000000000000001) reward -1
# total states 182401 end at (-0.004171078951138168, -0.009000000000000001) reward 0
# total states 182701 end at (-0.06562770282140011, 0.01) reward -1
# total states 183001 end at (-0.23162770282140022, 0.004) reward -1
# total states 183301 end at (0.35637229717860014, 0.007) reward -1
# total states 183601 end at (0.27682892104886203, -0.004) reward -1
# total states 183901 end at (0.2643722971786001, 0.002) reward -1
# total states 184201 end at (0.36037229717860014, 0.0) reward -1
# total states 184501 end at (0.060372297178599904, 0.003) reward -1
# total states 184801 end at (0.3003722971786001, 0.007) reward -1
# total states 185101 end at (0.035828921048861845, -0.008) reward -1
# total states 185401 end at (-0.27562770282140026, 0.007) reward -1
# total states 185701 end at (-0.3066277028214003, 0.007) reward -1
# total states 186001 end at (-0.3166277028214003, -0.01) reward -1
# total states 186301 end at (-0.24217107895113835, -0.003) reward -1
# total states 186601 end at (-0.2116277028214002, 0.002) reward -1
# total states 186901 end at (0.18882892104886195, -0.01) reward -1
# total states 187201 end at (0.14682892104886192, -0.004) reward -1
# total states 187501 end at (0.3598289210488621, 0.003) reward -1
# total states 187801 end at (0.3368289210488621, 0.001) reward -1
# total states 188101 end at (-0.01417107895113808, -0.01) reward -1
# total states 188401 end at (-0.20117107895113823, -0.005) reward -1
# total states 188701 end at (0.07437229717859994, 0.009000000000000001) reward -1
# total states 189001 end at (-0.1036277028214001, 0.009000000000000001) reward -1
# total states 189301 end at (-0.24262770282140023, 0.003) reward -1
# total states 189601 end at (0.28082892104886203, -0.003) reward -1
# total states 189901 end at (0.32282892104886207, 0.005) reward -1
# total states 190201 end at (0.3308289210488621, -0.001) reward -1
# total states 190501 end at (0.027372297178599937, 0.0) reward -1
# total states 190801 end at (-0.010627702821400069, 0.007) reward -1
# total states 191101 end at (-0.19662770282140019, 0.008) reward -1
# total states 191401 end at (0.34837229717860013, 0.009000000000000001) reward -1
# total states 191701 end at (-0.006627702821400093, 0.009000000000000001) reward -1
# total states 192001 end at (-0.013627702821400148, 0.008) reward 0
# total states 192301 end at (0.16182892104886193, -0.01) reward -1
# total states 192601 end at (0.23037229717860008, 0.006) reward -1
# total states 192901 end at (0.1203722971786, 0.0) reward -1
# total states 193201 end at (0.29882892104886205, -0.008) reward -1
# total states 193501 end at (-0.16617107895113817, -0.006) reward -1
# total states 193801 end at (-0.02062770282140007, 0.008) reward -1
# total states 194101 end at (0.3488289210488621, -0.002) reward -1
# total states 194401 end at (-0.3161710789511383, -0.006) reward -1
# total states 194701 end at (-0.24662770282140023, 0.003) reward -1
# total states 195001 end at (0.270828921048862, -0.009000000000000001) reward -1
# total states 195301 end at (-0.3136277028214003, 0.006) reward -1
# total states 195601 end at (-0.1571710789511381, -0.007) reward -1
# total states 195901 end at (0.3558289210488621, -0.008) reward -1
# total states 196201 end at (0.13037229717859994, 0.008) reward -1
# total states 196501 end at (0.35137229717860013, 0.008) reward -1
# total states 196801 end at (0.01182892104886185, -0.006) reward -1
# total states 197101 end at (-0.3266277028214003, -0.004) reward -1
# total states 197401 end at (-0.26962770282140025, 0.002) reward -1
# total states 197701 end at (0.31082892104886206, -0.004) reward -1
# total states 198001 end at (0.11182892104886191, -0.01) reward -1
# total states 198301 end at (0.18437229717860001, 0.01) reward -1
# total states 198601 end at (0.30982892104886206, -0.008) reward -1
# total states 198901 end at (0.12082892104886189, -0.009000000000000001) reward -1
# total states 199201 end at (0.28282892104886204, 0.004) reward -1
# total states 199501 end at (0.257828921048862, 0.0) reward -1
# total states 199801 end at (-0.04617107895113817, -0.003) reward -1
# total states 200101 end at (0.251828921048862, -0.006) reward -1
# total states 200401 end at (-0.16662770282140016, 0.007) reward -1
# total states 200701 end at (0.29282892104886205, -0.002) reward -1
# total states 201001 end at (0.3033722971786001, 0.003) reward -1
# total states 201301 end at (0.29282892104886205, -0.002) reward -1
# total states 201601 end at (-0.23862770282140022, -0.001) reward -1
# total states 201901 end at (0.12237229717859993, 0.008) reward -1
# total states 202201 end at (-0.3131710789511383, -0.007) reward -1
# total states 202501 end at (-0.23262770282140022, 0.0) reward -1
# total states 202801 end at (-0.00017107895113813512, -0.01) reward 0
# total states 203101 end at (-0.1996277028214002, 0.008) reward -1
# total states 203401 end at (0.051372297178599945, 0.01) reward -1
# total states 203701 end at (-0.23162770282140022, 0.001) reward -1
# total states 204001 end at (-0.27162770282140025, 0.008) reward -1
# total states 204301 end at (0.15882892104886193, -0.01) reward -1
# total states 204601 end at (0.06937229717859988, 0.006) reward -1
# total states 204901 end at (0.3603722971786001, 0.008) reward -1
# total states 205201 end at (0.29682892104886205, -0.003) reward -1
# total states 205501 end at (0.31582892104886207, -0.001) reward -1
# total states 205801 end at (-0.14862770282140014, 0.005) reward -1
# total states 206101 end at (0.30882892104886206, -0.007) reward -1
# total states 206401 end at (0.15182892104886192, -0.01) reward -1
# total states 206701 end at (-0.26462770282140025, 0.002) reward -1
# total states 207001 end at (-0.24662770282140023, 0.002) reward -1
# total states 207301 end at (0.022828921048861868, -0.01) reward 0
# total states 207601 end at (-0.2226277028214002, 0.003) reward -1
# total states 207901 end at (-0.2186277028214002, 0.003) reward -1
# total states 208201 end at (-0.023171078951138166, -0.01) reward -1
# total states 208501 end at (0.3578289210488621, -0.008) reward -1
# total states 208801 end at (0.28582892104886204, 0.004) reward -1
# total states 209101 end at (-0.11717107895113818, -0.004) reward -1
# total states 209401 end at (-0.23062770282140022, 0.002) reward -1
# total states 209701 end at (-0.19662770282140019, 0.006) reward -1
# total states 210001 end at (-0.11262770282140011, 0.009000000000000001) reward -1
# total states 210301 end at (-0.2256277028214002, 0.001) reward -1
# total states 210601 end at (-0.26562770282140025, 0.0) reward -1
# total states 210901 end at (-0.038627702821400045, -0.007) reward -1
# total states 211201 end at (-0.26562770282140025, 0.002) reward -1
# total states 211501 end at (-0.26662770282140025, 0.0) reward -1
# total states 211801 end at (0.21482892104886198, -0.01) reward -1
# total states 212101 end at (-0.26662770282140025, 0.002) reward -1
# total states 212401 end at (0.33637229717860007, 0.006) reward -1
# total states 212701 end at (-0.28862770282140027, 0.002) reward -1
# total states 213001 end at (-0.27662770282140026, -0.003) reward -1
# total states 213301 end at (-0.13862770282140013, 0.005) reward -1
# total states 213601 end at (-0.17962770282140017, 0.006) reward -1
# ...
# total states 229201 end at (-0.006627702821400067, 0.002) reward 0
# total states 229501 end at (-0.25762770282140024, 0.003) reward -1
# total states 229801 end at (0.29882892104886205, -0.001) reward -1
# total states 230101 end at (0.15582892104886192, -0.01) reward -1
# total states 230401 end at (-0.12717107895113824, -0.006) reward -1
# total states 230701 end at (-0.3116277028214003, -0.007) reward -1
# total states 231001 end at (0.3408289210488621, 0.001) reward -1
# total states 231301 end at (-0.19662770282140019, 0.007) reward -1
# total states 231601 end at (-0.31817107895113833, -0.007) reward -1
# total states 231901 end at (-0.15762770282140012, -0.005) reward -1
# total states 232201 end at (-0.2686277028214002, -0.007) reward -1
# total states 232501 end at (0.10537229717859997, -0.002) reward -1
# total states 232801 end at (0.09737229717859996, 0.001) reward -1
# total states 233101 end at (0.039372297178599865, 0.006) reward 0
# total states 233401 end at (0.16737229717859997, 0.007) reward -1
# total states 233701 end at (-0.25662770282140024, -0.001) reward -1
# total states 234001 end at (-0.28962770282140027, 0.0) reward -1
# total states 234301 end at (-0.27162770282140025, 0.002) reward -1
# total states 234601 end at (-0.27762770282140026, 0.003) reward -1
# total states 234901 end at (0.05337229717859987, 0.002) reward -1
# total states 235201 end at (-0.29162770282140027, 0.003) reward -1
# total states 235501 end at (-0.16762770282140016, -0.001) reward -1
# total states 235801 end at (-0.07262770282140008, 0.005) reward -1
# total states 236101 end at (0.09782892104886187, 0.002) reward -1
# total states 236401 end at (-0.0946277028214001, 0.004) reward -1
# total states 236701 end at (-0.24962770282140012, -0.008) reward -1
# total states 237001 end at (-0.24217107895113826, 0.002) reward -1
# total states 237301 end at (-0.27562770282140026, -0.007) reward -1
# total states 237601 end at (-0.2196277028214002, 0.001) reward -1
# total states 237901 end at (-0.07062770282140013, -0.003) reward -1
# total states 238201 end at (-0.1726277028214002, -0.002) reward -1
# total states 238501 end at (-0.14562770282140014, -0.006) reward -1
# total states 238801 end at (0.10037229717859997, 0.001) reward -1
# total states 239101 end at (0.22582892104886199, -0.003) reward -1
# total states 239401 end at (-0.23662770282140022, 0.003) reward -1
# total states 239701 end at (0.17582892104886194, -0.01) reward -1
# total states 240001 end at (-0.028627702821400078, 0.001) reward -1
# total states 240301 end at (0.038372297178599926, -0.003) reward -1
# total states 240601 end at (0.07037229717859995, 0.005) reward -1
# total states 240901 end at (0.30737229717860004, 0.006) reward -1
# total states 241201 end at (-0.3106277028214003, -0.007) reward -1
# total states 241501 end at (0.08037229717859995, 0.001) reward -1
# total states 241801 end at (0.019372297178599902, -0.002) reward -1
# total states 242101 end at (0.255828921048862, -0.009000000000000001) reward -1
# total states 242401 end at (0.12882892104886204, 0.0) reward -1
# total states 242701 end at (0.07382892104886199, -0.003) reward 0
# total states 243001 end at (0.022828921048861812, 0.0) reward -1
# total states 243301 end at (-0.25862770282140024, 0.002) reward -1
# total states 243601 end at (-0.27762770282140026, 0.003) reward -1
# total states 243901 end at (0.11737229717860001, 0.008) reward -1
# total states 244201 end at (0.03637229717859996, 0.003) reward -1
# total states 244501 end at (0.09637229717859998, -0.001) reward -1
# total states 244801 end at (0.09437229717859992, -0.001) reward -1
# total states 245101 end at (0.07337229717859999, 0.001) reward -1
# total states 245401 end at (-0.32917107895113834, -0.007) reward -1
# total states 245701 end at (0.30182892104886205, -0.002) reward -1
# total states 246001 end at (-0.3196277028214003, -0.006) reward -1
# total states 246301 end at (-0.1061710789511382, -0.008) reward -1
# total states 246601 end at (-0.3176277028214003, -0.008) reward -1
# total states 246901 end at (-0.15162770282140015, -0.004) reward -1
# total states 247201 end at (-0.28262770282140026, 0.003) reward -1
# total states 247501 end at (-0.3266277028214003, 0.006) reward -1
# total states 247801 end at (0.013828921048861846, -0.009000000000000001) reward -1
# total states 248101 end at (-0.18717107895113824, -0.01) reward -1
# total states 248401 end at (-0.2276277028214002, -0.001) reward -1
# total states 248701 end at (-0.24462770282140023, 0.001) reward -1
# total states 249001 end at (-0.29262770282140027, 0.005) reward -1
# total states 249301 end at (-0.06962770282140009, -0.006) reward -1
# total states 249601 end at (-0.27062770282140025, 0.005) reward -1
# total states 249901 end at (0.10982892104886194, 0.001) reward -1
# total states 250201 end at (0.08737229717859994, 0.005) reward -1
# total states 250501 end at (0.01437229717859994, 0.0) reward -1
# total states 250801 end at (0.3613722971786002, 0.003) reward -1
# total states 251101 end at (-0.10617107895113817, -0.007) reward -1
# total states 251401 end at (0.04637229717859996, -0.003) reward -1
# total states 251701 end at (0.08837229717859994, 0.004) reward -1
# total states 252001 end at (-0.15062770282140014, 0.004) reward -1
# total states 252301 end at (-0.14762770282140014, -0.004) reward -1
# total states 252601 end at (-0.22117107895113827, -0.01) reward -1
# total states 252901 end at (-0.17262770282140016, 0.0) reward -1
# total states 253201 end at (0.0053722971785999, 0.002) reward -1
# total states 253501 end at (-0.03162770282140008, 0.004) reward -1
# total states 253801 end at (-0.1081710789511382, -0.004) reward -1
# total states 254101 end at (0.09137229717859993, 0.002) reward -1
# total states 254401 end at (-0.2686277028214003, -0.006) reward -1
# total states 254701 end at (0.02237229717859991, -0.004) reward -1
# total states 255001 end at (0.10337229717859998, -0.001) reward -1
# total states 255301 end at (-0.25262770282140024, 0.005) reward -1
# total states 255601 end at (-0.05862770282140006, 0.004) reward -1
# total states 255901 end at (0.08737229717859996, -0.002) reward -1
# total states 256201 end at (0.2853722971786001, 0.001) reward -1
# total states 256501 end at (0.09437229717859996, 0.005) reward -1
# total states 256801 end at (0.06937229717859994, 0.006) reward 0
# total states 257101 end at (0.01682892104886191, -0.009000000000000001) reward -1
# total states 257401 end at (0.07537229717859992, 0.001) reward -1
# total states 257701 end at (0.255828921048862, 0.001) reward -1
# total states 258001 end at (-0.09562770282140015, -0.005) reward -1
# total states 258301 end at (0.09037229717859994, 0.005) reward -1
# total states 258601 end at (-0.08217107895113819, -0.004) reward -1
# total states 258901 end at (0.051372297178599924, 0.004) reward -1
# total states 259201 end at (0.17637229717860003, 0.006) reward -1
# total states 259501 end at (0.07037229717859993, -0.001) reward -1
# total states 259801 end at (-0.10817107895113819, 0.0) reward -1
# total states 260101 end at (-0.13517107895113822, -0.002) reward -1
# total states 260401 end at (0.1013722971785999, 0.004) reward -1
# total states 260701 end at (-0.12362770282140012, -0.004) reward -1
# total states 261001 end at (-0.12717107895113822, -0.003) reward -1
# total states 261301 end at (-0.09617107895113818, -0.005) reward -1
# total states 261601 end at (-0.2046277028214002, 0.004) reward -1
# total states 261901 end at (-0.13362770282140013, -0.006) reward -1
# total states 262201 end at (-0.14462770282140014, 0.009000000000000001) reward -1
# total states 262501 end at (0.16037229717859997, 0.009000000000000001) reward -1
# total states 262801 end at (-0.016171078951138108, -0.001) reward -1
# total states 263101 end at (-0.17262770282140016, 0.002) reward -1
# total states 263401 end at (-0.1986277028214002, 0.008) reward -1
# total states 263701 end at (-0.17462770282140017, 0.0) reward -1
# total states 264001 end at (0.2578289210488619, 0.007) reward -1
# total states 264301 end at (-0.06462770282140007, 0.006) reward -1
# total states 264601 end at (-0.10517107895113822, -0.003) reward -1
# total states 264901 end at (-0.08562770282140009, 0.002) reward -1
# total states 265201 end at (-0.048627702821400096, -0.002) reward -1
# total states 265501 end at (0.16637229717860003, 0.005) reward -1
# total states 265801 end at (-0.0731710789511382, -0.004) reward -1
# total states 266101 end at (-0.07017107895113812, -0.01) reward -1
# total states 266401 end at (0.0063722971785999186, 0.002) reward -1
# total states 266701 end at (-0.09362770282140012, -0.002) reward -1
# total states 267001 end at (0.34037229717860007, 0.007) reward -1
# total states 267301 end at (0.3308289210488621, 0.009000000000000001) reward -1
# total states 267601 end at (-0.12362770282140015, -0.002) reward -1
# total states 267901 end at (-0.2186277028214002, 0.009000000000000001) reward -1
# total states 268201 end at (-0.12862770282140013, 0.007) reward -1
# total states 268501 end at (-0.10262770282140013, -0.004) reward -1
# total states 268801 end at (0.3588289210488621, 0.005) reward -1
# total states 269101 end at (-0.2196277028214002, 0.004) reward -1
# total states 269401 end at (0.27882892104886203, -0.003) reward -1
# total states 269701 end at (-0.16162770282140015, 0.009000000000000001) reward -1
# total states 270001 end at (0.2503722971786, 0.0) reward -1
# total states 270301 end at (-0.11962770282140012, -0.004) reward -1
# total states 270601 end at (-0.17517107895113823, -0.003) reward -1
# total states 270901 end at (-0.2591710789511383, 0.002) reward -1
# total states 271201 end at (-0.3056277028214003, 0.007) reward -1
# total states 271501 end at (-0.23062770282140022, 0.009000000000000001) reward -1
# total states 271801 end at (-0.08662770282140012, 0.009000000000000001) reward -1
# total states 272101 end at (-0.15962770282140015, 0.009000000000000001) reward -1
# total states 272401 end at (-0.059627702821400064, 0.004) reward -1
# total states 272701 end at (0.13237229717859994, 0.0) reward -1
# total states 273001 end at (0.09437229717859996, -0.007) reward -1
# total states 273301 end at (-0.2266277028214002, -0.002) reward -1
# total states 273601 end at (-0.2961710789511383, -0.005) reward -1
# total states 273901 end at (0.263828921048862, -0.005) reward -1
# total states 274201 end at (0.3698289210488621, 0.004) reward -1
# total states 274501 end at (0.230828921048862, -0.003) reward -1
# total states 274801 end at (-0.3276277028214002, -0.005) reward -1
# total states 275101 end at (-0.20717107895113834, -0.003) reward -1
# total states 275401 end at (-0.23762770282140022, 0.004) reward -1
# total states 275701 end at (-0.025627702821400134, -0.005) reward -1
# total states 276001 end at (-0.20517107895113826, -0.007) reward -1
# total states 276301 end at (-0.031627702821400136, 0.008) reward -1
# total states 276601 end at (0.3753722971786002, 0.008) reward -1
# total states 276901 end at (0.19437229717860005, 0.005) reward -1
# total states 277201 end at (0.259828921048862, -0.008) reward -1
# total states 277501 end at (0.045828921048861854, -0.001) reward -1
# total states 277801 end at (-0.23462770282140022, 0.006) reward -1
# total states 278101 end at (-0.010627702821400051, 0.005) reward 0
# total states 278401 end at (0.3803722971786002, 0.003) reward -1
# total states 278701 end at (-0.13517107895113822, -0.004) reward -1
# total states 279001 end at (-0.2226277028214002, 0.005) reward -1
# total states 279301 end at (0.3583722971786001, 0.008) reward -1
# total states 279601 end at (-0.3126277028214003, -0.006) reward -1
# total states 279901 end at (-0.003627702821400112, -0.001) reward -1
# total states 280201 end at (0.01982892104886185, -0.007) reward -1
# total states 280501 end at (-0.22517107895113822, -0.003) reward -1
# total states 280801 end at (-0.008627702821400077, -0.001) reward -1
# total states 281101 end at (0.24837229717860004, -0.001) reward -1
# total states 281401 end at (0.2713722971786, 0.002) reward -1
# total states 281701 end at (-0.0856277028214001, -0.002) reward -1
# total states 282001 end at (-0.2831710789511383, 0.002) reward -1
# total states 282301 end at (0.09937229717859992, -0.001) reward -1
# total states 282601 end at (-0.011627702821400077, 0.002) reward -1
# total states 282901 end at (0.07382892104886185, -0.004) reward -1
# total states 283201 end at (-0.04462770282140013, 0.008) reward -1
# total states 283501 end at (-0.040627702821400075, 0.004) reward -1
# total states 283801 end at (0.245828921048862, -0.01) reward -1
# total states 284101 end at (0.10537229717859997, -0.002) reward -1
# total states 284401 end at (0.07382892104886188, -0.01) reward -1
# total states 284701 end at (0.237828921048862, 0.005) reward -1
# total states 285001 end at (-0.11117107895113819, -0.006) reward -1
# total states 285301 end at (0.13937229717859997, 0.002) reward -1
# total states 285601 end at (0.10982892104886187, 0.003) reward -1
# total states 285901 end at (0.264828921048862, -0.01) reward -1
# total states 286201 end at (0.258828921048862, 0.001) reward -1
# total states 286501 end at (0.08982892104886187, -0.008) reward -1
# total states 286801 end at (-0.1551710789511381, -0.006) reward -1
# total states 287101 end at (0.0363722971785999, 0.005) reward -1
# total states 287401 end at (-0.09162770282140009, 0.009000000000000001) reward -1
# total states 287701 end at (0.37637229717860016, 0.007) reward -1
# total states 288001 end at (-0.2741710789511383, -0.008) reward -1
# total states 288301 end at (0.257828921048862, -0.006) reward -1
# total states 288601 end at (-0.06662770282140011, 0.001) reward -1
# total states 288901 end at (0.12082892104886189, -0.009000000000000001) reward -1
# total states 289201 end at (0.025372297178599915, 0.003) reward -1
# total states 289501 end at (0.19682892104886196, -0.01) reward -1
# total states 289801 end at (0.056372297178599894, 0.005) reward -1
# total states 290101 end at (-0.03462770282140006, -0.005) reward -1
# total states 290401 end at (0.11437229717859988, 0.005) reward -1
# total states 290701 end at (0.16682892104886193, -0.01) reward -1
# total states 291001 end at (-0.13362770282140013, 0.007) reward -1
# total states 291301 end at (0.18137229717859996, 0.005) reward -1
# total states 291601 end at (-0.09162770282140012, 0.009000000000000001) reward -1
# total states 291901 end at (-0.1826277028214002, -0.003) reward -1
# total states 292201 end at (-0.1381710789511382, -0.004) reward -1
# total states 292501 end at (0.03482892104886183, 0.001) reward -1
# total states 292801 end at (0.06637229717859991, -0.007) reward -1
# total states 293101 end at (0.17037229717860003, 0.007) reward -1
# total states 293401 end at (-0.08162770282140011, -0.008) reward -1
# total states 293701 end at (-0.23362770282140022, 0.005) reward -1
# total states 294001 end at (0.22282892104886198, -0.008) reward -1
# total states 294301 end at (-0.1251710789511381, 0.01) reward -1
# total states 294601 end at (-0.28017107895113824, 0.001) reward -1
# total states 294901 end at (-0.17117107895113814, -0.009000000000000001) reward -1
# total states 295201 end at (0.3523722971786, 0.002) reward -1
# total states 295501 end at (0.32137229717860005, 0.006) reward -1
# total states 295801 end at (0.3773722971786001, 0.008) reward -1
# total states 296101 end at (-0.14417107895113815, -0.008) reward -1
# total states 296401 end at (-0.007627702821400159, -0.001) reward -1
# total states 296701 end at (-0.0456277028214001, 0.008) reward -1
# total states 297001 end at (0.1693722971786, 0.0) reward -1
# total states 297301 end at (0.11037229717859992, 0.001) reward -1
# total states 297601 end at (0.005828921048861845, -0.007) reward 0
# total states 297901 end at (0.27537229717859996, 0.004) reward -1
# total states 298201 end at (0.39337229717860006, 0.007) reward -1
# total states 298501 end at (0.3823722971786001, 0.009000000000000001) reward -1
# total states 298801 end at (-0.2676277028214002, -0.01) reward -1
# total states 299101 end at (0.10137229717859988, 0.0) reward -1
# total states 299401 end at (0.1048289210488619, -0.01) reward -1
# total states 299701 end at (0.22637229717859994, 0.008) reward -1

# %% [markdown]
# ## 4. Visualisation
#
# * What we need more for this part
#
# 1.We need to draw a graphs to compare real heartbeat / predicted heartbeat values.

# %% [markdown]
# ### Comparing between true data and predicted results

# %%
grids = len(data)
time_step = np.linspace(1, len(data), len(data))

predicted_positions = []


for i in range(len(predicted_states)):
    predicted_position = []
    
    for j in range(len(data)):
        predicted_position.append(predicted_states[i][j][0])
    
    predicted_positions.append(predicted_position)
    
    label = "Run: " + str(i+1)
    
    plt.figure(figsize=(20,6))    
    plt.plot(time_step, predicted_position, label = label)
    plt.plot(time_step, data, label = "Original data")
    plt.legend()
    plt.show()
    
#linestyle=":"

# %%
import pickle

pickle.dump(predicted_positions, open( "tdlambda_entire3000000.pickle", "wb" ) )

# %% [markdown]
# ### RMSE Prop

# %%
reward_batch = 1

# %%
import math

start = 0
end = 0
RMSE_values = []

for pred in predicted_positions:
    start = 0
    end = 0
    RMSE_value = []
    
    for i in range(1, len(data)):
        
        if i % reward_batch == 0:
            start = end
            end = end + reward_batch
            
            true_batch = data[:end]
            predict_batch = pred[:end]
            
            MSE = np.square(np.subtract(true_batch,predict_batch)).mean()
            RMSE = math.sqrt(MSE)
            
            RMSE_value.append(RMSE)
            
    RMSE_values.append(RMSE_value)

# %%
plt.figure(figsize=(20,6))

for i in range(len(RMSE_values)):
    
    grids = len(RMSE_values[i])
    step = np.linspace(1, len(RMSE_values[i]), len(RMSE_values[i]))
    label = "RMSE for run# " + str(i+1)
    
    plt.plot(step, RMSE_values[i], label = label)

plt.legend()
plt.show()

# %% [markdown]
# ### Cost graph

# %%
grids = 50

positions = np.linspace(POSITION_BOUND[0][0], POSITION_BOUND[0][1], grids)
vels = np.linspace(GAP_BOUND[0], GAP_BOUND[1], grids)

x = []
y = []
z = []
for p in positions:
    for v in vels:
        x.append(p)
        y.append(v)
        z.append(valueFunc.stepcost([p, v]))

fig = plt.figure(figsize=[10, 6])
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)

ax.set_xlabel("Beat status")
ax.set_ylabel("Gap")
ax.set_zlabel("Cost")
# Out:
# Text(0.5, 0, 'Cost')
